# %% [markdown]
# Only run this file if there are problems with Plotly's image exports not detecting Chrome.

# %%
import plotly.io as pio

pio.get_chrome()
# Out:
# PosixPath('/Users/agari/Projects/grant-pt/env/lib/python3.12/site-packages/choreographer/cli/browser_exe/chrome-mac-arm64/Google Chrome for Testing.app/Contents/MacOS/Google Chrome for Testing')
