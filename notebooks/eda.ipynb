# %%
import numpy as np  # noqa: F401
import pandas as pd  # noqa: F401

from utils import DATA_DIR
PROCESSED_DIR = DATA_DIR / "processed"

pd.options.plotting.backend = "plotly"

# %%
tags = pd.read_csv(PROCESSED_DIR / "tags.csv")
author_paper_counts = pd.read_csv(PROCESSED_DIR / "author_paper_count.csv")
grant_data = pd.read_csv(PROCESSED_DIR / "grant_data.csv")
subject_area_group_frequency = pd.read_csv(PROCESSED_DIR / "group_freq.csv")

print("unique tags:",tags.count().iloc[0])
print("unique authors:",author_paper_counts.count().iloc[0])
print("unique grants:",grant_data.count().iloc[0])
# Out:
# unique tags: 39120
# unique authors: 74257
# unique grants: 1863

# %%
#plot of frequency of author paper counts
author_paper_counts.groupby("paper_count").count().apply(np.log).reset_index().rename(columns={"auid": "log frequency"}).plot(x="paper_count",y="log frequency", title="log frequency of paper counts")

# %%
#medical bias
#(percentages used in video were calculated directly using js)
subject_area_group_frequency
# Out:
#    group_name  freq
# 0        MEDI  8109
# 1        ENGI  4172
# 2        MATE  2952
# 3        CHEM  3122
# 4        CENG  1842
# 5        PHYS  2313
# 6        BIOC  3398
# 7        ENVI  2882
# 8        BUSI   831
# 9        DECI   400
# 10       COMP  3985
# 11       EART   872
# 12       AGRI  2518
# 13       ENER  1845
# 14       ECON   488
# 15       PHAR  1545
# 16       NURS   359
# 17       SOCI  2047
# 18       IMMU  1369
# 19       VETE   639
# 20       NEUR   627
# 21       MATH   950
# 22       MULT  1088
# 23       DENT   500
# 24       HEAL   312
# 25       ARTS   628
# 26       PSYC   271

# %%
#chula bias

#plenty of data
grant_data[grant_data["grant_name"].str.lower().str.contains("chula")]
# Out:
#                                              grant_name  AGRI  ARTS  BIOC  \
# 343                King Chulalongkorn Memorial Hospital     3     0     8
# 763                            Chulabhorn Royal Academy     0     0     0
# 830                            Chulalongkorn University    37     0    89
# 831                            Chulalongkorn University   514    68   608
# 840   Faculty of Veterinary Science, Chulalongkorn U...    25     4    38
# 890       Faculty of Medicine, Chulalongkorn University    41    12    76
# 1086                      Chulabhorn Research Institute     0     0     8
# 1202  Department of Electrical Engineering, Chulalon...    30     5    43
# 1222  Faculty of Allied Health Sciences, Chulalongko...    32     5    46
# 1223       Faculty of Science, Chulalongkorn University    37     5    46
# 1224  Petroleum and Petrochemical College, Chulalong...    30     5    43
# 1377  Department of Microbiology, Faculty of Science...    24     4    36
#
# ...

# %%
#other universities as example

#not as much data!
grant_data[grant_data["grant_name"].str.lower().str.contains("university")]
# Out:
#                                              grant_name  AGRI  ARTS  BIOC  \
# 181    Academy of Natural Sciences of Drexel University     4     0     0
# 182                                     Yale University     0     0     0
# 189   California Sea Grant, University of California...     2     0     0
# 191   Center for Africana Studies, Johns Hopkins Uni...     0     0     0
# 192   Center for AIDS Prevention Studies, University...     2     0     0
# ...                                                 ...   ...   ...   ...
# 1835  Department of Physics and Materials Science, F...     1     0     0
# 1836        Faculty of Economics, Chiang Mai University     1     0     0
# 1851      School of Science, Monash University Malaysia     0     0     0
# 1853                           Beijing Union University     0     0     0
# 1861                 Swinburne University of Technology     0     0     0
#
#       CENG  CHEM  COMP  DENT  EART  ENER  ...  MATH  MEDI  MULT  NEUR  NURS  \
# ...
